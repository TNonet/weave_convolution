# %%
import numpy as np
import tensorflow as tf
from weave import *
from keras.datasets import cifar10
from keras.utils.np_utils import to_categorical
# Out:
# /Users/Tim/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print(x_train.shape)
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)
print(y_test.shape)
# Out:
# (50000, 3, 32, 32)
# (10000, 10)

# %%
layers = 2
filters = 5
epochs = 10
pool = False

# %%
model2 = in_line_net(layers, filters, 'param', max_pool_alt=pool)
model2.summary()
model = build_pyrm_net(layers, filters, max_pool_alt=pool)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3, 32, 32)         0
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 3, 34, 34)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 32, 32)        280
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 10, 34, 34)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 32, 32)         455
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 16, 16)         0
# _________________________________________________________________
# zero_padding2d_3 (ZeroPaddin (None, 5, 18, 18)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 16, 16)        920
# _________________________________________________________________
# zero_padding2d_4 (ZeroPaddin (None, 20, 18, 18)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 16, 16)        1810
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 8, 8)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 640)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               64100
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 68,575
# Trainable params: 68,575
# Non-trainable params: 0
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 3, 32, 32)    0
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 3, 34, 34)    0           input_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 3, 34, 34)    0           input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 5, 32, 32)    140         zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 5, 32, 32)    140         zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 5, 32, 32)    140         zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 5, 32, 32)    140         zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# array_weave_1 (ArrayWeave)      (None, 5, 94, 94)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# zero_weave_1 (ZeroWeave)        (None, 5, 94, 94)    0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# array_weave_2 (ArrayWeave)      (None, 5, 94, 94)    0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# zero_weave_2 (ZeroWeave)        (None, 5, 94, 94)    0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 5, 94, 94)    0           array_weave_1[0][0]
#                                                                  zero_weave_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 5, 94, 94)    0           array_weave_2[0][0]
#                                                                  zero_weave_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 5, 96, 96)    0           add_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 5, 96, 96)    0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 5, 32, 32)    230         zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 5, 32, 32)    230         zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 5, 16, 16)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 5, 16, 16)    0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 5, 18, 18)    0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 5, 18, 18)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 10, 16, 16)   460         zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 10, 16, 16)   460         zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# array_weave_3 (ArrayWeave)      (None, 10, 46, 46)   0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# zero_weave_3 (ZeroWeave)        (None, 10, 46, 46)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 10, 46, 46)   0           array_weave_3[0][0]
#                                                                  zero_weave_3[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 10, 48, 48)   0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 10, 16, 16)   910         zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 10, 8, 8)     0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 640)          0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 100)          64100       flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10)           1010        dense_3[0][0]
# ==================================================================================================
# Total params: 67,960
# Trainable params: 67,960
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
viewer = keras.callbacks.TensorBoard(log_dir='./logs', histogram_freq=0, batch_size=32, write_graph=True)
model2.fit(x_train[0:100], y_train[0:100], callbacks=[viewer])
# Out:
# Epoch 1/1
# 100/100 [==============================] - 1s 8ms/step - loss: 10.3032 - acc: 0.1200

# %%
model.fit(x_train,y_train, epochs = epochs, verbose = 1)
print(model.evaluate(x_test,y_test))
# Out:
# Epoch 1/10
# 50000/50000 [==============================] - 964s 19ms/step - loss: 1.9237 - acc: 0.3804
# Epoch 2/10
# 50000/50000 [==============================] - 6883s 138ms/step - loss: 1.3944 - acc: 0.4992
# Epoch 3/10
# 50000/50000 [==============================] - 1016s 20ms/step - loss: 1.2672 - acc: 0.5467
# Epoch 4/10
# 50000/50000 [==============================] - 1036s 21ms/step - loss: 1.1799 - acc: 0.5790
# Epoch 5/10
# 50000/50000 [==============================] - 1057s 21ms/step - loss: 1.1135 - acc: 0.6035
# Epoch 6/10
# 50000/50000 [==============================] - 1136s 23ms/step - loss: 1.0527 - acc: 0.6228
# Epoch 7/10
# 50000/50000 [==============================] - 1094s 22ms/step - loss: 1.0068 - acc: 0.6427
# Epoch 8/10
# 50000/50000 [==============================] - 932s 19ms/step - loss: 0.9681 - acc: 0.6558
# Epoch 9/10
# 50000/50000 [==============================] - 925s 18ms/step - loss: 0.9303 - acc: 0.6676
# Epoch 10/10
# 50000/50000 [==============================] - 924s 18ms/step - loss: 0.8936 - acc: 0.6831
# 10000/10000 [==============================] - 89s 9ms/step
# [1.2217380395889281, 0.5817]

# %%
model2.fit(x_train,y_train, epochs = epochs, verbose = 1)
print(model2.evaluate(x_test,y_test))
# Out:
# Epoch 1/10
# 50000/50000 [==============================] - 243s 5ms/step - loss: 1.7166 - acc: 0.3933
# Epoch 2/10
# 50000/50000 [==============================] - 245s 5ms/step - loss: 1.3047 - acc: 0.5377
# Epoch 3/10
# 50000/50000 [==============================] - 244s 5ms/step - loss: 1.1732 - acc: 0.5856
# Epoch 4/10
# 50000/50000 [==============================] - 244s 5ms/step - loss: 1.0883 - acc: 0.6165
# Epoch 5/10
# 50000/50000 [==============================] - 246s 5ms/step - loss: 1.0178 - acc: 0.6404
# Epoch 6/10
# 50000/50000 [==============================] - 245s 5ms/step - loss: 0.9579 - acc: 0.6625
# Epoch 7/10
# 50000/50000 [==============================] - 244s 5ms/step - loss: 0.9077 - acc: 0.6790
# Epoch 8/10
# 50000/50000 [==============================] - 245s 5ms/step - loss: 0.8641 - acc: 0.6943
# Epoch 9/10
# 50000/50000 [==============================] - 246s 5ms/step - loss: 0.8272 - acc: 0.7058
# Epoch 10/10
# 50000/50000 [==============================] - 247s 5ms/step - loss: 0.7926 - acc: 0.7203
# 10000/10000 [==============================] - 28s 3ms/step
# [1.2135585611343385, 0.6008]
