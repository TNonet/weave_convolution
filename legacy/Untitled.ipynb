# %%
import numpy as np
import tensorflow as tf
from pyrm_net import *
from keras.datasets import cifar10
from keras.utils.np_utils import to_categorical
from non_weave_iso_net import *
# Out:
# /Users/Tim/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print(x_train.shape)
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)
print(y_test.shape)
# Out:
# (50000, 3, 32, 32)
# (10000, 10)

# %%
layers = 2
filters = 5
epochs = 10
pool = False

# %%
model = build_pyrm_net(layers, filters, max_pool_alt=pool)
model.summary()
model2 = in_line_net(layers, filters, 'param', max_pool_alt=pool)
model2.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3, 32, 32)    0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 3, 34, 34)    0           input_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 3, 34, 34)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 5, 32, 32)    140         zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 5, 32, 32)    140         zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 5, 32, 32)    140         zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 5, 32, 32)    140         zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# array_weave_1 (ArrayWeave)      (None, 5, 94, 94)    0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# zero_weave_1 (ZeroWeave)        (None, 5, 94, 94)    0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# array_weave_2 (ArrayWeave)      (None, 5, 94, 94)    0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# zero_weave_2 (ZeroWeave)        (None, 5, 94, 94)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 5, 94, 94)    0           array_weave_1[0][0]
#                                                                  zero_weave_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 5, 94, 94)    0           array_weave_2[0][0]
#                                                                  zero_weave_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 5, 96, 96)    0           add_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 5, 96, 96)    0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 5, 32, 32)    230         zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 5, 32, 32)    230         zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 5, 16, 16)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 5, 16, 16)    0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 5, 18, 18)    0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 5, 18, 18)    0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 5, 16, 16)    230         zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 5, 16, 16)    230         zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# array_weave_3 (ArrayWeave)      (None, 5, 46, 46)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# zero_weave_3 (ZeroWeave)        (None, 5, 46, 46)    0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 5, 46, 46)    0           array_weave_3[0][0]
#                                                                  zero_weave_3[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 5, 48, 48)    0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 5, 16, 16)    230         zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 5, 8, 8)      0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 320)          0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          32100       flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10)           1010        dense_1[0][0]
# ==================================================================================================
# Total params: 34,820
# Trainable params: 34,820
# Non-trainable params: 0
# __________________________________________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 3, 32, 32)         0
# _________________________________________________________________
# zero_padding2d_8 (ZeroPaddin (None, 3, 34, 34)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 10, 32, 32)        280
# _________________________________________________________________
# zero_padding2d_9 (ZeroPaddin (None, 10, 34, 34)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 5, 32, 32)         455
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 16, 16)         0
# _________________________________________________________________
# zero_padding2d_10 (ZeroPaddi (None, 5, 18, 18)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 10, 16, 16)        460
# _________________________________________________________________
# zero_padding2d_11 (ZeroPaddi (None, 10, 18, 18)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 5, 16, 16)         455
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 5, 8, 8)           0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 320)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               32100
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 34,760
# Trainable params: 34,760
# Non-trainable params: 0
# _________________________________________________________________

# %%
# viewer = keras.callbacks.TensorBoard(log_dir='./logs', histogram_freq=0, batch_size=32, write_graph=True)
# model2.fit(x_train[0:100], y_train[0:100], callbacks=[viewer])

# %%
model.fit(x_train,y_train, epochs = epochs, verbose = 1)
print(model.evaluate(x_test,y_test))
# Out:
# Epoch 1/10
# 50000/50000 [==============================] - 1812s 36ms/step - loss: 1.8978 - acc: 0.3396
# Epoch 2/10
# 50000/50000 [==============================] - 876s 18ms/step - loss: 1.5397 - acc: 0.4436
# Epoch 3/10
# 50000/50000 [==============================] - 850s 17ms/step - loss: 1.4307 - acc: 0.4839
# Epoch 4/10
# 50000/50000 [==============================] - 1502s 30ms/step - loss: 1.3556 - acc: 0.5141
# Epoch 5/10
# 50000/50000 [==============================] - 867s 17ms/step - loss: 1.2960 - acc: 0.5368
# Epoch 6/10
# 50000/50000 [==============================] - 825s 16ms/step - loss: 1.2474 - acc: 0.5551
# Epoch 7/10
# 50000/50000 [==============================] - 838s 17ms/step - loss: 1.2120 - acc: 0.5699
# Epoch 8/10
# 50000/50000 [==============================] - 828s 17ms/step - loss: 1.1817 - acc: 0.5805
# Epoch 9/10
# 50000/50000 [==============================] - 1362s 27ms/step - loss: 1.1464 - acc: 0.5949
# Epoch 10/10
# 50000/50000 [==============================] - 3971s 79ms/step - loss: 1.1232 - acc: 0.6005
# 10000/10000 [==============================] - 89s 9ms/step
# [1.248066969871521, 0.5597]

# %%
model2.fit(x_train,y_train, epochs = epochs, verbose = 1)
print(model2.evaluate(x_test,y_test))
# Out:
# Epoch 1/10
# 50000/50000 [==============================] - 242s 5ms/step - loss: 1.8488 - acc: 0.3307
# Epoch 2/10
# 50000/50000 [==============================] - 233s 5ms/step - loss: 1.5247 - acc: 0.4477
# Epoch 3/10
# 50000/50000 [==============================] - 241s 5ms/step - loss: 1.3836 - acc: 0.5039
# Epoch 4/10
# 50000/50000 [==============================] - 231s 5ms/step - loss: 1.3029 - acc: 0.5331
# Epoch 5/10
# 50000/50000 [==============================] - 235s 5ms/step - loss: 1.2456 - acc: 0.5545
# Epoch 6/10
# 50000/50000 [==============================] - 212s 4ms/step - loss: 1.1991 - acc: 0.5723
# Epoch 7/10
# 50000/50000 [==============================] - 214s 4ms/step - loss: 1.1552 - acc: 0.5900
# Epoch 8/10
# 50000/50000 [==============================] - 210s 4ms/step - loss: 1.1212 - acc: 0.6032
# Epoch 9/10
# 50000/50000 [==============================] - 209s 4ms/step - loss: 1.0982 - acc: 0.6087
# Epoch 10/10
# 50000/50000 [==============================] - 212s 4ms/step - loss: 1.0632 - acc: 0.6210
# 10000/10000 [==============================] - 25s 3ms/step
# [1.276862632751465, 0.565]
